# %%
#Problem6:Remove Duplicate Phone Numbers
def remove_duplicate_phone_numbers(phone_numbers): 
    unique_phone_numbers=set(phone_numbers)  
    return unique_phone_numbers

phone_numbers=[9876543210,9123456789,9876543210]
unique_numbers=remove_duplicate_phone_numbers(phone_numbers) 
print(f"Unique phone numbers:{unique_numbers}")
# Out:
# Unique phone numbers: {9876543210, 9123456789}
