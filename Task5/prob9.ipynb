# %%
#program to determine student attendance eligibility for exams
def attendance_eligibility(attendance_list):
    total_classes=len(attendance_list)
    attended_classes=0

    for status in attendance_list:
        attended_classes+=status
    attendance_percentage=(attended_classes/total_classes)*100
    
    if attendance_percentage>=75:
        eligibility="Eligible"
    else:
        eligibility="Not Eligible"
    print("Attendance Percentage:",attendance_percentage)
    print("Exam Eligibility:",eligibility)

student_attendance=[1,1,1,1,0]  
attendance_eligibility(student_attendance)
# Out:
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible
