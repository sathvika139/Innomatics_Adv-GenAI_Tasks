# %%
#program to monitor medicine stock levels and alert when low
def medicine_stock_alert(stock):
    if stock < 10:
        status="Low Stock Alert"
    else:
        status="Stock Sufficient"
    print("Medicine Stock:",stock)
    print("Status:",status)

current_stock=6
medicine_stock_alert(current_stock)
# Out:
# Medicine Stock: 6
# Status: Low Stock Alert
