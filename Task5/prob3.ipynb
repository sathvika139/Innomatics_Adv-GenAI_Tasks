# %%
#program to analyze rainfall data and determine if it meets required levels
def rainfall_checker(rainfall_data,required_level):
    total_rainfall=0
    
    for rainfall in rainfall_data:
        total_rainfall+=rainfall
    average_rainfall=total_rainfall/len(rainfall_data)
    
    if average_rainfall>=required_level:
        status="Adequate Rainfall"
    else:
        status="Inadequate Rainfall"
    print("Average Rainfall:", int(average_rainfall))
    print("Rainfall Status:", status)

seasonal_data=[70,75,68,80,67]  
required_rainfall_level=70
rainfall_checker(seasonal_data,required_rainfall_level)
# Out:
# Average Rainfall: 72
# Rainfall Status: Adequate Rainfall
