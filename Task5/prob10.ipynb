# %%
#program to analyze electricity bill based on smart meter readings
def electricity_bill_analyzer(units):
    bill=0
    if units<=100:
        bill=units*3
    elif units<=200:
        bill=(100*3)+(units-100)*5
    else:
        bill=(100*3)+(100*5)+(units-200)*7

    if bill<500:
        usage_status="Low Usage"
    elif bill<=1500:
        usage_status="Moderate Usage"
    else:
        usage_status="High Usage"
    return bill,usage_status

units_consumed=250
total_bill,status=electricity_bill_analyzer(units_consumed)
print("Units Consumed:",units_consumed)
print("Total Bill: ₹",total_bill)
print("Usage Level:",status)
# Out:
# Units Consumed: 250
# Total Bill: ₹ 1150
# Usage Level: Moderate Usage
